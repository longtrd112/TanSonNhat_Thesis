# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# Set the font name and size
font_name = "Times New Roman"
font_size = 13

# Set the global font properties
rcParams['font.family'] = font_name
rcParams['font.size'] = font_size
name = ['first latitude', 'first longitude', 'first altitude',
       'first ground speed', 'first heading angle', 'second latitude',
       'second longitude', 'second altitude', 'second ground speed',
       'second heading angle', 'entry TMA latitude', 'entry TMA longitude',
       'entry TMA altitude', 'entry TMA ground speed', 'entry TMA heading angle',
       'wind speed', 'visibility', 'skyc1', 'model type', 'landing runway direction']
value = [0.02566639, 0.03843539, 0.02621583, 0.04421709, 0.02597431, 0.03924584,
 0.03983609, 0.11259522, 0.03316729, 0.02433312, 0.07864861, 0.07146662,
 0.20420887, 0.06092918, 0.05508666, 0.02045468, 0.05778635, 0.00687651,
 0.00288007, 0.03197588]

zn = [name for _,name in sorted(zip(value,name), reverse=True)]

vn = sorted(value, reverse=True)
print(zn, vn)

plt.barh(zn, vn)
plt.xlabel('Feature importance')
plt.gca().invert_yaxis()
# Out:
# ['entry TMA altitude', 'second altitude', 'entry TMA latitude', 'entry TMA longitude', 'entry TMA ground speed', 'visibility', 'entry TMA heading angle', 'first ground speed', 'second longitude', 'second latitude', 'first longitude', 'second ground speed', 'landing runway direction', 'first altitude', 'first heading angle', 'first latitude', 'second heading angle', 'wind speed', 'skyc1', 'model type'] [0.20420887, 0.11259522, 0.07864861, 0.07146662, 0.06092918, 0.05778635, 0.05508666, 0.04421709, 0.03983609, 0.03924584, 0.03843539, 0.03316729, 0.03197588, 0.02621583, 0.02597431, 0.02566639, 0.02433312, 0.02045468, 0.00687651, 0.00288007]
